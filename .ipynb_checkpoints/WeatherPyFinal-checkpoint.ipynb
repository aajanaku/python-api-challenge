# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes. Why are we grouping the cities in sets of 50?
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    params= {'q':city,'appid':weather_api_key,'units':'imperial'}
    city_url = url
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url, params=params).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
    # To limit the number of cities for testing purposes. What does this have to do with grouping? Why are we doing this?
    #if i > 10:
        #break

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | nadym
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | mariental
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | bilibino
# Processing Record 7 of Set 1 | ariguani
# Processing Record 8 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 1 | merizo village
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | olonkinbyen
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | revda
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | wailua homesteads
# Processing Record 18 of Set 1 | west island
# Processing Record 19 of Set 1 | hoima
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | qaqortoq
# Processing Record 22 of Set 1 | alice springs
# Processing Record 23 of Set 1 | nuuk
# Processing Record 24 of Set 1 | udachny
# Processing Record 25 of Set 1 | la passe
# Processing Record 26 of Set 1 | tomok bolon
# City not found. Skipping...
# Processing Record 27 of Set 1 | trujillo
# Processing Record 28 of Set 1 | presidente medici
# Processing Record 29 of Set 1 | saynshand
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | kulhudhuffushi
# Processing Record 33 of Set 1 | center
# Processing Record 34 of Set 1 | bathsheba
# Processing Record 35 of Set 1 | walvis bay
# Processing Record 36 of Set 1 | jiangyou
# Processing Record 37 of Set 1 | hammerfest
# Processing Record 38 of Set 1 | adamstown
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 1 | mukalla
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | aasiaat
# Processing Record 45 of Set 1 | vilyuysk
# Processing Record 46 of Set 1 | port blair
# Processing Record 47 of Set 1 | chegdomyn
# Processing Record 48 of Set 1 | remire-montjoly
# Processing Record 49 of Set 1 | bikenibeu village
# Processing Record 50 of Set 1 | edinburgh of the seven seas
# Processing Record 0 of Set 2 | touros
# Processing Record 1 of Set 2 | invercargill
# Processing Record 2 of Set 2 | waitangi
# Processing Record 3 of Set 2 | blackmans bay
# Processing Record 4 of Set 2 | papatowai
# Processing Record 5 of Set 2 | badger
# Processing Record 6 of Set 2 | waspan
# Processing Record 7 of Set 2 | hawaiian paradise park
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | noumea
# Processing Record 10 of Set 2 | gorontalo
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | puerto baquerizo moreno
# Processing Record 13 of Set 2 | nikol'sk
# Processing Record 14 of Set 2 | shangri-la
# City not found. Skipping...
# Processing Record 15 of Set 2 | alwar
# Processing Record 16 of Set 2 | enewetak
# Processing Record 17 of Set 2 | suwayr
# Processing Record 18 of Set 2 | cortina d'ampezzo
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | camargo
# Processing Record 21 of Set 2 | oualidia
# City not found. Skipping...
# Processing Record 22 of Set 2 | kirensk
# Processing Record 23 of Set 2 | pihani
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | hadibu
# Processing Record 26 of Set 2 | quellon
# Processing Record 27 of Set 2 | guli
# Processing Record 28 of Set 2 | whitehorse
# Processing Record 29 of Set 2 | nar'yan-mar
# Processing Record 30 of Set 2 | nova sintra
# Processing Record 31 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | vilyuchinsk
# Processing Record 35 of Set 2 | san clemente del tuyu
# Processing Record 36 of Set 2 | noshiro
# Processing Record 37 of Set 2 | el nido
# Processing Record 38 of Set 2 | zaragoza
# Processing Record 39 of Set 2 | porto novo
# Processing Record 40 of Set 2 | weno
# Processing Record 41 of Set 2 | turpan
# Processing Record 42 of Set 2 | nagqu
# Processing Record 43 of Set 2 | utrik
# Processing Record 44 of Set 2 | kem'
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | sortavala
# Processing Record 47 of Set 2 | acapulco de juarez
# Processing Record 48 of Set 2 | ixtapa
# Processing Record 49 of Set 2 | xinzhou
# Processing Record 0 of Set 3 | fort stockton
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | timbuktu
# Processing Record 3 of Set 3 | constantia
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | itoman
# Processing Record 7 of Set 3 | launceston
# Processing Record 8 of Set 3 | darwin
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | brownwood
# Processing Record 11 of Set 3 | susuman
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | honcho
# Processing Record 15 of Set 3 | newnham
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | los zacatones
# Processing Record 18 of Set 3 | alofi
# Processing Record 19 of Set 3 | dudinka
# Processing Record 20 of Set 3 | panadura
# Processing Record 21 of Set 3 | trairi
# Processing Record 22 of Set 3 | pacific grove
# Processing Record 23 of Set 3 | margate
# Processing Record 24 of Set 3 | san fernando
# Processing Record 25 of Set 3 | mersa matruh
# Processing Record 26 of Set 3 | cestos city
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | tazovsky
# Processing Record 29 of Set 3 | kingsville
# Processing Record 30 of Set 3 | port mathurin
# Processing Record 31 of Set 3 | mbarara
# Processing Record 32 of Set 3 | nova vicosa
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | mamuju
# Processing Record 35 of Set 3 | kingston
# Processing Record 36 of Set 3 | keflavik
# Processing Record 37 of Set 3 | dhalie
# Processing Record 38 of Set 3 | bhimunipatnam
# Processing Record 39 of Set 3 | galveston
# Processing Record 40 of Set 3 | elmendorf air force base
# City not found. Skipping...
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | puerto deseado
# Processing Record 43 of Set 3 | flying fish cove
# Processing Record 44 of Set 3 | margaret river
# Processing Record 45 of Set 3 | port-cartier
# Processing Record 46 of Set 3 | shilovo
# Processing Record 47 of Set 3 | iskateley
# Processing Record 48 of Set 3 | santa maria del oro
# Processing Record 49 of Set 3 | broome
# Processing Record 0 of Set 4 | primero de mayo
# Processing Record 1 of Set 4 | hami
# Processing Record 2 of Set 4 | sogndal
# Processing Record 3 of Set 4 | arkalyk
# Processing Record 4 of Set 4 | juneau
# Processing Record 5 of Set 4 | mount pearl
# Processing Record 6 of Set 4 | hoxtolgay
# City not found. Skipping...
# Processing Record 7 of Set 4 | kodinsk
# Processing Record 8 of Set 4 | sandpoint
# Processing Record 9 of Set 4 | island harbour
# Processing Record 10 of Set 4 | yatou
# Processing Record 11 of Set 4 | taoudenni
# Processing Record 12 of Set 4 | myrina
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 15 of Set 4 | belmonte
# Processing Record 16 of Set 4 | es castell
# Processing Record 17 of Set 4 | geraldton
# Processing Record 18 of Set 4 | vorgashor
# Processing Record 19 of Set 4 | blenheim
# Processing Record 20 of Set 4 | kavaratti
# Processing Record 21 of Set 4 | forest
# Processing Record 22 of Set 4 | zhatay
# Processing Record 23 of Set 4 | crane
# Processing Record 24 of Set 4 | balaipungut
# Processing Record 25 of Set 4 | ternate
# Processing Record 26 of Set 4 | olyokminsk
# Processing Record 27 of Set 4 | quepos
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | kununurra
# Processing Record 30 of Set 4 | kapuskasing
# Processing Record 31 of Set 4 | mili
# Processing Record 32 of Set 4 | la rinconada
# Processing Record 33 of Set 4 | east london
# Processing Record 34 of Set 4 | tura
# Processing Record 35 of Set 4 | afaahiti
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | lautoka
# Processing Record 38 of Set 4 | peace river
# Processing Record 39 of Set 4 | luderitz
# Processing Record 40 of Set 4 | lihue
# Processing Record 41 of Set 4 | sisimiut
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | caleta de carquin
# Processing Record 44 of Set 4 | labrador city
# Processing Record 45 of Set 4 | bredasdorp
# Processing Record 46 of Set 4 | yunfu
# Processing Record 47 of Set 4 | grants
# Processing Record 48 of Set 4 | saldanha
# Processing Record 49 of Set 4 | atafu village
# Processing Record 0 of Set 5 | tarinkot
# Processing Record 1 of Set 5 | buka
# Processing Record 2 of Set 5 | ponta delgada
# Processing Record 3 of Set 5 | kavalerovo
# Processing Record 4 of Set 5 | ivankiv
# Processing Record 5 of Set 5 | sinabang
# Processing Record 6 of Set 5 | bonga
# Processing Record 7 of Set 5 | codrington
# Processing Record 8 of Set 5 | breaux bridge
# Processing Record 9 of Set 5 | klyuchi
# Processing Record 10 of Set 5 | arteche
# Processing Record 11 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 12 of Set 5 | tazacorte
# Processing Record 13 of Set 5 | dogonbadan
# Processing Record 14 of Set 5 | st. john's
# Processing Record 15 of Set 5 | isle of lewis
# City not found. Skipping...
# Processing Record 16 of Set 5 | rizokarpaso
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | nieuw nickerie
# Processing Record 19 of Set 5 | zangguy
# City not found. Skipping...
# Processing Record 20 of Set 5 | aberdeen
# Processing Record 21 of Set 5 | johi
# Processing Record 22 of Set 5 | bahia de caraquez
# Processing Record 23 of Set 5 | usogorsk
# Processing Record 24 of Set 5 | santa ana de yacuma
# Processing Record 25 of Set 5 | selfoss
# Processing Record 26 of Set 5 | sur
# Processing Record 27 of Set 5 | igrim
# Processing Record 28 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 29 of Set 5 | cheremukhovo
# Processing Record 30 of Set 5 | murashi
# Processing Record 31 of Set 5 | hakui
# Processing Record 32 of Set 5 | kone
# Processing Record 33 of Set 5 | ardakan
# Processing Record 34 of Set 5 | koh kong
# Processing Record 35 of Set 5 | chudovo
# Processing Record 36 of Set 5 | ola
# Processing Record 37 of Set 5 | tralee
# Processing Record 38 of Set 5 | saipan
# Processing Record 39 of Set 5 | rikaze
# Processing Record 40 of Set 5 | bamboo flat
# Processing Record 41 of Set 5 | ketchikan
# Processing Record 42 of Set 5 | lata
# Processing Record 43 of Set 5 | salina cruz
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | aykhal
# Processing Record 46 of Set 5 | bodri
# Processing Record 47 of Set 5 | harstad
# Processing Record 48 of Set 5 | guerrero negro
# Processing Record 49 of Set 5 | bhadrachalam
# Processing Record 0 of Set 6 | okhotsk
# Processing Record 1 of Set 6 | serchhip
# Processing Record 2 of Set 6 | opuwo
# Processing Record 3 of Set 6 | guiria
# City not found. Skipping...
# Processing Record 4 of Set 6 | howard springs
# Processing Record 5 of Set 6 | al mayadin
# Processing Record 6 of Set 6 | 'alaqahdari dishu
# Processing Record 7 of Set 6 | college
# Processing Record 8 of Set 6 | mostaganem
# Processing Record 9 of Set 6 | bel ombre
# Processing Record 10 of Set 6 | forster
# Processing Record 11 of Set 6 | sindgi
# Processing Record 12 of Set 6 | drayton valley
# Processing Record 13 of Set 6 | tocopilla
# Processing Record 14 of Set 6 | marrakesh
# Processing Record 15 of Set 6 | debark'
# Processing Record 16 of Set 6 | inayauan
# Processing Record 17 of Set 6 | quiberon
# Processing Record 18 of Set 6 | laojunmiao
# Processing Record 19 of Set 6 | mata-utu
# Processing Record 20 of Set 6 | thompson
# Processing Record 21 of Set 6 | stanley
# Processing Record 22 of Set 6 | praia
# Processing Record 23 of Set 6 | vila franca do campo
# Processing Record 24 of Set 6 | sangmelima
# Processing Record 25 of Set 6 | carutapera
# Processing Record 26 of Set 6 | aljezur
# Processing Record 27 of Set 6 | kralendijk
# Processing Record 28 of Set 6 | enterprise
# Processing Record 29 of Set 6 | mizdah
# Processing Record 30 of Set 6 | khandyga
# Processing Record 31 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 32 of Set 6 | hithadhoo
# Processing Record 33 of Set 6 | tolanaro
# Processing Record 34 of Set 6 | dapa
# Processing Record 35 of Set 6 | certaldo
# Processing Record 36 of Set 6 | quelimane
# Processing Record 37 of Set 6 | bouna
# Processing Record 38 of Set 6 | kargasok
# Processing Record 39 of Set 6 | huarmey
# Processing Record 40 of Set 6 | san gabriel
# Processing Record 41 of Set 6 | serdar
# Processing Record 42 of Set 6 | kushiro
# Processing Record 43 of Set 6 | mikhaylovskoye
# Processing Record 44 of Set 6 | moranbah
# Processing Record 45 of Set 6 | ad dabbah
# Processing Record 46 of Set 6 | valparaiso
# Processing Record 47 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 48 of Set 6 | haiku-pauwela
# Processing Record 49 of Set 6 | colonia
# Processing Record 0 of Set 7 | piti village
# Processing Record 1 of Set 7 | amursk
# Processing Record 2 of Set 7 | tempio pausania
# Processing Record 3 of Set 7 | el bolson
# Processing Record 4 of Set 7 | murun-kuren
# Processing Record 5 of Set 7 | kunyang
# Processing Record 6 of Set 7 | zakopane
# Processing Record 7 of Set 7 | gadzhiyevo
# Processing Record 8 of Set 7 | watampone
# Processing Record 9 of Set 7 | helong
# Processing Record 10 of Set 7 | san jose del guaviare
# Processing Record 11 of Set 7 | auki
# Processing Record 12 of Set 7 | san pedro pochutla
# Processing Record 13 of Set 7 | punta cardon
# Processing Record 14 of Set 7 | manokwari
# Processing Record 15 of Set 7 | anadyr
# Processing Record 16 of Set 7 | adilcevaz
# Processing Record 17 of Set 7 | champerico
# Processing Record 18 of Set 7 | den burg
# Processing Record 19 of Set 7 | tarauaca
# Processing Record 20 of Set 7 | hola
# Processing Record 21 of Set 7 | scottburgh
# Processing Record 22 of Set 7 | shimanovsk
# Processing Record 23 of Set 7 | sovetskiy
# Processing Record 24 of Set 7 | mar del plata
# Processing Record 25 of Set 7 | mount gambier
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | general acha
# Processing Record 28 of Set 7 | asau village
# City not found. Skipping...
# Processing Record 29 of Set 7 | sarmiento
# Processing Record 30 of Set 7 | lebu
# Processing Record 31 of Set 7 | luau
# Processing Record 32 of Set 7 | severoural'sk
# Processing Record 33 of Set 7 | labytnangi
# Processing Record 34 of Set 7 | pulsano
# Processing Record 35 of Set 7 | isafjordur
# Processing Record 36 of Set 7 | linxia chengguanzhen
# Processing Record 37 of Set 7 | safford
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | kaltungo
# Processing Record 40 of Set 7 | ilgin
# Processing Record 41 of Set 7 | brisas de zicatela
# Processing Record 42 of Set 7 | san luis de la loma
# Processing Record 43 of Set 7 | chibougamau
# Processing Record 44 of Set 7 | el porvenir
# Processing Record 45 of Set 7 | emmett
# Processing Record 46 of Set 7 | mirny
# Processing Record 47 of Set 7 | nizip
# Processing Record 48 of Set 7 | avarua
# Processing Record 49 of Set 7 | arraial do cabo
# Processing Record 0 of Set 8 | kaa-khem
# Processing Record 1 of Set 8 | as sulayyil
# Processing Record 2 of Set 8 | pasni
# Processing Record 3 of Set 8 | al qanayat
# Processing Record 4 of Set 8 | mahina
# Processing Record 5 of Set 8 | madang
# Processing Record 6 of Set 8 | shahin dezh
# Processing Record 7 of Set 8 | fale old settlement
# Processing Record 8 of Set 8 | faya-largeau
# Processing Record 9 of Set 8 | sungai penuh
# Processing Record 10 of Set 8 | san carlos del zulia
# Processing Record 11 of Set 8 | qinzhou
# Processing Record 12 of Set 8 | beypazari
# Processing Record 13 of Set 8 | plastun
# Processing Record 14 of Set 8 | haverfordwest
# Processing Record 15 of Set 8 | el jadid
# Processing Record 16 of Set 8 | aleksandrovskoye
# Processing Record 17 of Set 8 | newman
# Processing Record 18 of Set 8 | dolisie
# Processing Record 19 of Set 8 | whitburn
# Processing Record 20 of Set 8 | aztec
# Processing Record 21 of Set 8 | lakhipur
# Processing Record 22 of Set 8 | ulanhot
# Processing Record 23 of Set 8 | kabwe
# Processing Record 24 of Set 8 | san antonio de pale
# Processing Record 25 of Set 8 | cockburn town
# Processing Record 26 of Set 8 | tiznit
# Processing Record 27 of Set 8 | keminmaa
# Processing Record 28 of Set 8 | noormarkku
# Processing Record 29 of Set 8 | tabou
# Processing Record 30 of Set 8 | natal
# Processing Record 31 of Set 8 | eldoret
# Processing Record 32 of Set 8 | dubbo
# Processing Record 33 of Set 8 | lianhe
# Processing Record 34 of Set 8 | kuvshinovo
# Processing Record 35 of Set 8 | coahuayana de hidalgo
# Processing Record 36 of Set 8 | sao jose da coroa grande
# Processing Record 37 of Set 8 | llanes
# Processing Record 38 of Set 8 | saint-francois
# Processing Record 39 of Set 8 | kudahuvadhoo
# Processing Record 40 of Set 8 | petrovsk-zabaykal'skiy
# Processing Record 41 of Set 8 | al fuwayliq
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | altamont
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | kolobrzeg
# Processing Record 46 of Set 8 | shilka
# Processing Record 47 of Set 8 | sinop
# Processing Record 48 of Set 8 | rabaul
# Processing Record 49 of Set 8 | mazatlan
# Processing Record 0 of Set 9 | zhumadian
# Processing Record 1 of Set 9 | sarupathar
# Processing Record 2 of Set 9 | antsiranana
# Processing Record 3 of Set 9 | fernie
# Processing Record 4 of Set 9 | ulladulla
# Processing Record 5 of Set 9 | brookings
# Processing Record 6 of Set 9 | nepalgunj
# Processing Record 7 of Set 9 | kiunga
# Processing Record 8 of Set 9 | tlapanaloya
# City not found. Skipping...
# Processing Record 9 of Set 9 | bandar abbas
# Processing Record 10 of Set 9 | narara
# Processing Record 11 of Set 9 | leer
# Processing Record 12 of Set 9 | ceerigaabo
# Processing Record 13 of Set 9 | sanjwal
# Processing Record 14 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 9 | petauke
# Processing Record 16 of Set 9 | barcelona
# Processing Record 17 of Set 9 | mochudi
# Processing Record 18 of Set 9 | villa gesell
# Processing Record 19 of Set 9 | sylvan lake
# Processing Record 20 of Set 9 | kharan
# Processing Record 21 of Set 9 | chonchi
# Processing Record 22 of Set 9 | bereket
# Processing Record 23 of Set 9 | kongolo
# Processing Record 24 of Set 9 | reggane
# Processing Record 25 of Set 9 | igarka
# Processing Record 26 of Set 9 | veraval
# Processing Record 27 of Set 9 | copiapo
# Processing Record 28 of Set 9 | carnot
# Processing Record 29 of Set 9 | daru
# Processing Record 30 of Set 9 | maceio
# Processing Record 31 of Set 9 | hasaki
# Processing Record 32 of Set 9 | khanty-mansiysk
# Processing Record 33 of Set 9 | paredon
# Processing Record 34 of Set 9 | derzhavinsk
# Processing Record 35 of Set 9 | kansk
# Processing Record 36 of Set 9 | hede
# Processing Record 37 of Set 9 | mananara
# Processing Record 38 of Set 9 | thunder bay
# Processing Record 39 of Set 9 | dazhong
# Processing Record 40 of Set 9 | zapala
# Processing Record 41 of Set 9 | port isabel
# Processing Record 42 of Set 9 | el calafate
# Processing Record 43 of Set 9 | uturoa
# Processing Record 44 of Set 9 | sechura
# Processing Record 45 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 9 | cassilandia
# Processing Record 47 of Set 9 | orapa
# Processing Record 48 of Set 9 | zaozersk
# Processing Record 49 of Set 9 | north battleford
# Processing Record 0 of Set 10 | andirin
# Processing Record 1 of Set 10 | loiza
# Processing Record 2 of Set 10 | cidade velha
# Processing Record 3 of Set 10 | princeville
# Processing Record 4 of Set 10 | ulsteinvik
# Processing Record 5 of Set 10 | yangquan
# Processing Record 6 of Set 10 | paraiso
# Processing Record 7 of Set 10 | ciudad acuna
# Processing Record 8 of Set 10 | barah
# Processing Record 9 of Set 10 | atherton
# Processing Record 10 of Set 10 | vadso
# Processing Record 11 of Set 10 | muisne
# Processing Record 12 of Set 10 | krasnoslobodsk
# Processing Record 13 of Set 10 | dalhart
# Processing Record 14 of Set 10 | peniche
# Processing Record 15 of Set 10 | xining
# Processing Record 16 of Set 10 | bafoulabe
# Processing Record 17 of Set 10 | clarence town
# Processing Record 18 of Set 10 | arawa
# Processing Record 19 of Set 10 | mejit
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | sao lourenco do sul
# Processing Record 22 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 23 of Set 10 | misratah
# Processing Record 24 of Set 10 | arenapolis
# Processing Record 25 of Set 10 | ylivieska
# Processing Record 26 of Set 10 | dedza
# Processing Record 27 of Set 10 | ancud
# Processing Record 28 of Set 10 | flin flon
# Processing Record 29 of Set 10 | longboat key
# Processing Record 30 of Set 10 | san patricio
# Processing Record 31 of Set 10 | esquipulas
# Processing Record 32 of Set 10 | oranjemund
# Processing Record 33 of Set 10 | mindelo
# Processing Record 34 of Set 10 | port saint john's
# Processing Record 35 of Set 10 | alo
# Processing Record 36 of Set 10 | nsanje
# Processing Record 37 of Set 10 | jiuquan
# Processing Record 38 of Set 10 | yelizovo
# Processing Record 39 of Set 10 | tangalle
# Processing Record 40 of Set 10 | papao
# Processing Record 41 of Set 10 | kantunilkin
# Processing Record 42 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 43 of Set 10 | cabo san lucas
# Processing Record 44 of Set 10 | prince rupert
# Processing Record 45 of Set 10 | nemuro
# Processing Record 46 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 10 | kerikeri
# Processing Record 48 of Set 10 | tamandare
# Processing Record 49 of Set 10 | carire
# Processing Record 0 of Set 11 | pama
# Processing Record 1 of Set 11 | regina
# Processing Record 2 of Set 11 | bhakkar
# Processing Record 3 of Set 11 | kyren
# Processing Record 4 of Set 11 | melo
# Processing Record 5 of Set 11 | akureyri
# Processing Record 6 of Set 11 | moussoro
# Processing Record 7 of Set 11 | dhuusamarreeb
# Processing Record 8 of Set 11 | tateyama
# Processing Record 9 of Set 11 | minas de marcona
# Processing Record 10 of Set 11 | katra
# Processing Record 11 of Set 11 | west bay
# Processing Record 12 of Set 11 | khilok
# Processing Record 13 of Set 11 | san juan de miraflores
# Processing Record 14 of Set 11 | carbonear
# Processing Record 15 of Set 11 | adra
# Processing Record 16 of Set 11 | funafuti
# Processing Record 17 of Set 11 | mount isa
# Processing Record 18 of Set 11 | jinxiang
# Processing Record 19 of Set 11 | fort bragg
# Processing Record 20 of Set 11 | si satchanalai
# Processing Record 21 of Set 11 | amos
# Processing Record 22 of Set 11 | tsiombe
# Processing Record 23 of Set 11 | filey
# Processing Record 24 of Set 11 | ayod
# City not found. Skipping...
# Processing Record 25 of Set 11 | alesund
# Processing Record 26 of Set 11 | gobabis
# Processing Record 27 of Set 11 | czersk
# Processing Record 28 of Set 11 | sola
# Processing Record 29 of Set 11 | ust-nera
# Processing Record 30 of Set 11 | kendari
# Processing Record 31 of Set 11 | cajaruro
# Processing Record 32 of Set 11 | perth
# Processing Record 33 of Set 11 | gwaram
# Processing Record 34 of Set 11 | angra do heroismo
# Processing Record 35 of Set 11 | rakvere
# Processing Record 36 of Set 11 | fort-shevchenko
# Processing Record 37 of Set 11 | tocache
# Processing Record 38 of Set 11 | qashyr
# Processing Record 39 of Set 11 | oyama
# Processing Record 40 of Set 11 | wagar
# Processing Record 41 of Set 11 | farasan
# Processing Record 42 of Set 11 | al fujairah city
# Processing Record 43 of Set 11 | karkira
# Processing Record 44 of Set 11 | grand falls-windsor
# Processing Record 45 of Set 11 | manaure
# Processing Record 46 of Set 11 | kirakira
# Processing Record 47 of Set 11 | al hazm
# Processing Record 48 of Set 11 | rancho palos verdes
# Processing Record 49 of Set 11 | qorovulbozor
# Processing Record 0 of Set 12 | buulobarde
# Processing Record 1 of Set 12 | payyannur
# Processing Record 2 of Set 12 | tirebolu
# Processing Record 3 of Set 12 | chilca
# Processing Record 4 of Set 12 | taro
# Processing Record 5 of Set 12 | kenai
# Processing Record 6 of Set 12 | tamanrasset
# Processing Record 7 of Set 12 | al kharj
# Processing Record 8 of Set 12 | al jawf
# Processing Record 9 of Set 12 | linden
# Processing Record 10 of Set 12 | happy valley-goose bay
# Processing Record 11 of Set 12 | upington
# Processing Record 12 of Set 12 | felipe carrillo puerto
# Processing Record 13 of Set 12 | apolinario saravia
# Processing Record 14 of Set 12 | selebi-phikwe
# Processing Record 15 of Set 12 | glace bay
# Processing Record 16 of Set 12 | sandnessjoen
# Processing Record 17 of Set 12 | lazaro cardenas
# Processing Record 18 of Set 12 | adam
# Processing Record 19 of Set 12 | anloga
# Processing Record 20 of Set 12 | sao joao da barra
# Processing Record 21 of Set 12 | nuku'alofa
# Processing Record 22 of Set 12 | cannonvale
# Processing Record 23 of Set 12 | cocachacra
# Processing Record 24 of Set 12 | bodo
# Processing Record 25 of Set 12 | namsos
# Processing Record 26 of Set 12 | bintulu
# Processing Record 27 of Set 12 | wakkanai
# Processing Record 28 of Set 12 | bengkulu
# Processing Record 29 of Set 12 | goz beida
# Processing Record 30 of Set 12 | douentza
# Processing Record 31 of Set 12 | baskale
# Processing Record 32 of Set 12 | aguililla
# Processing Record 33 of Set 12 | floro
# Processing Record 34 of Set 12 | jayapura
# Processing Record 35 of Set 12 | prado
# Processing Record 36 of Set 12 | kurchatov
# Processing Record 37 of Set 12 | san andres
# Processing Record 38 of Set 12 | azhikkal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# Your previous code to fetch weather data and store it in city_data list...

# After fetching weather data for all cities, create lists to hold the data
cities_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []

# Loop through the city_data list and extract data into respective lists
for city_info in city_data:
    cities_list.append(city_info["City"])
    lat_list.append(city_info["Lat"])
    lng_list.append(city_info["Lng"])
    max_temp_list.append(city_info["Max Temp"])
    humidity_list.append(city_info["Humidity"])
    cloudiness_list.append(city_info["Cloudiness"])
    wind_speed_list.append(city_info["Wind Speed"])
    country_list.append(city_info["Country"])
    date_list.append(city_info["Date"])

# Create a dictionary with the lists
weather_dict = {
    "City": cities_list,
    "Lat": lat_list,
    "Lng": lng_list,
    "Max Temp": max_temp_list,
    "Humidity": humidity_list,
    "Cloudiness": cloudiness_list,
    "Wind Speed": wind_speed_list,
    "Country": country_list,
    "Date": date_list
}

# Create the DataFrame using the dictionary
city_data_df = pd.DataFrame(weather_dict)

# Display the DataFrame
print(city_data_df)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      longyearbyen  78.2186   15.6401     48.04        57          75
# 1             nadym  65.5333   72.5167     66.20        64          35
# 2    port elizabeth -33.9180   25.5701     56.10        62          20
# 3         mariental -24.6333   17.9667     57.47        20           0
# 4       port alfred -33.5906   26.8910     58.17        65          70
# ..              ...      ...       ...       ...       ...         ...
# 561        jayapura  -2.5333  140.7000     78.19        88          96
# 562           prado -17.3411  -39.2208     72.93        87         100
# 563       kurchatov  51.6601   35.6521     77.41        47          73
# 564      san andres  12.5847  -81.7006     86.02        79          40
# 565        azhikkal  11.9000   75.3667     78.55        83          16
#
#      Wind Speed Country        Date
# 0         11.50      SJ  1690725992
# 1         15.55      RU  1690725993
# 2         26.46      ZA  1690725993
# 3          9.35      NA  1690725993
# 4         10.00      ZA  1690725994
# ..          ...     ...         ...
# 561        3.27      ID  1690726192
# 562       12.64      BR  1690726193
# 563        8.52      RU  1690726193
# 564       17.27      CO  1690726193
# 565        7.70      IN  1690726098
#
# [566 rows x 9 columns]

# %%
# Convert the cities weather data into a Pandas DataFrame
#  = YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    longyearbyen  78.2186  15.6401     48.04        57          75
# 1           nadym  65.5333  72.5167     66.20        64          35
# 2  port elizabeth -33.9180  25.5701     56.10        62          20
# 3       mariental -24.6333  17.9667     57.47        20           0
# 4     port alfred -33.5906  26.8910     58.17        65          70
#
#    Wind Speed Country        Date
# 0       11.50      SJ  1690725992
# 1       15.55      RU  1690725993
# 2       26.46      ZA  1690725993
# 3        9.35      NA  1690725993
# 4       10.00      ZA  1690725994

# %%
# Export the City_Data into a csv
city_data_df.to_csv('data_output2.csv', index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("data_output2.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          longyearbyen  78.2186  15.6401     48.04        57          75
# 1                 nadym  65.5333  72.5167     66.20        64          35
# 2        port elizabeth -33.9180  25.5701     56.10        62          20
# 3             mariental -24.6333  17.9667     57.47        20           0
# 4           port alfred -33.5906  26.8910     58.17        65          70
#
#          Wind Speed Country        Date
# City_ID
# 0             11.50      SJ  1690725992
# 1             15.55      RU  1690725993
# 2             26.46      ZA  1690725993
# 3              9.35     NaN  1690725993
# 4             10.00      ZA  1690725994

# %%
# Read saved data
city_data_df = pd.read_csv("data_output2.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          longyearbyen  78.2186  15.6401     48.04        57          75
# 1                 nadym  65.5333  72.5167     66.20        64          35
# 2        port elizabeth -33.9180  25.5701     56.10        62          20
# 3             mariental -24.6333  17.9667     57.47        20           0
# 4           port alfred -33.5906  26.8910     58.17        65          70
#
#          Wind Speed Country        Date
# City_ID
# 0             11.50      SJ  1690725992
# 1             15.55      RU  1690725993
# 2             26.46      ZA  1690725993
# 3              9.35     NaN  1690725993
# 4             10.00      ZA  1690725994

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
Max_Temp = city_data_df['Max Temp']
Lat = city_data_df['Lat']
plt.scatter(Max_Temp,Lat,edgecolor="black")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2023-07-26)")
plt.savefig("Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
Humidity = city_data_df['Humidity']
Lat = city_data_df['Lat']
plt.scatter(Humidity,Lat)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs. Humidity (2023-07-30)")
#plt.savefig("Fig2.png")
plt.show()

# Incorporate the other graph properties?
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
Cloudiness = city_data_df['Cloudiness']
Lat = city_data_df['Lat']
plt.scatter(Cloudiness,Lat)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness (2023-07-30)")
#plt.savefig("Fig3.png")
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = city_data_df['Wind Speed']
Lat = city_data_df['Lat']
plt.scatter(wind_speed,Lat)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed (2023-07-30)")
plt.savefig("Fig4.png")
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear(y_values,x_values,title,coords,xlabel,ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,coords,fontsize=15,color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    print(f"the r value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df=city_data_df[city_data_df['Lat']>=0]
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          longyearbyen  78.2186   15.6401     48.04        57          75
# 1                 nadym  65.5333   72.5167     66.20        64          35
# 5              bilibino  68.0546  166.4372     41.13        94         100
# 6              ariguani  10.2500  -74.0000     86.79        53         100
# 7        merizo village  13.2658  144.6691     81.99        96          53
#
#          Wind Speed Country        Date
# City_ID
# 0             11.50      SJ  1690725992
# 1             15.55      RU  1690725993
# 5              2.48      RU  1690725994
# 6              1.86      CO  1690725995
# 7              2.48      GU  1690725996

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df['Lat']<0]
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           port elizabeth -33.9180  25.5701     56.10        62          20
# 3                mariental -24.6333  17.9667     57.47        20           0
# 4              port alfred -33.5906  26.8910     58.17        65          70
# 11                 ushuaia -54.8000 -68.3000     33.46        64          40
# 13       port-aux-francais -49.3500  70.2167     35.04        72          51
#
#          Wind Speed Country        Date
# City_ID
# 2             26.46      ZA  1690725993
# 3              9.35     NaN  1690725993
# 4             10.00      ZA  1690725994
# 11            14.97      AR  1690725886
# 13            36.98      TF  1690725998

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear(northern_hemi_df["Max Temp"],northern_hemi_df["Lat"],"Latitude v. Max Temp (Northern)",(0,40),"Latitude",
"Max Temp")
# Out:
# the r value is: 0.34930871327665397

# %%
linear(southern_hemi_df["Max Temp"],southern_hemi_df["Lat"],"Latitude v. Max Temp (Southern)", (-30,40),"Latitude",
"Max Temp")
# Out:
# the r value is: 0.7897002288567664

# %% [markdown]
# **Discussion about the linear relationship:There is a clear linear relationship

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear(northern_hemi_df["Humidity"],northern_hemi_df["Lat"],"Latitude v. Humidity (Northern)", (45,10),"Latitude",
"Humidity")
# Out:
# the r value is: 0.003585725690750341

# %%
# Southern Hemisphere
linear(southern_hemi_df["Max Temp"],southern_hemi_df["Lat"],"Latitude v. Max Temp (Southern)", (-30,40),"Latitude",
"Humidity")
# Out:
# the r value is: 0.7897002288567664

# %% [markdown]
# **Discussion about the linear relationship: There is a clear linear relationship

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear(northern_hemi_df["Cloudiness"],northern_hemi_df["Lat"],"Cloudiness v. Latitude (Northern)",(45,60),"Latitude",
"Cloudiness")
# Out:
# the r value is: 0.003792869179121583

# %%
# Southern Hemisphere
linear(southern_hemi_df["Cloudiness"],southern_hemi_df["Lat"],"Cloudiness v. Latitude (Southern)",(-55,60),"Latitude",
"Cloudiness")
# Out:
# the r value is: 0.049256069846397015

# %% [markdown]
# **Discussion about the linear relationship:There is no linear relationship

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear(northern_hemi_df["Wind Speed"],northern_hemi_df["Lat"],"Wind Speed v. Latitude (Northern)",(-55,60),"Latitude",
"Wind Speed")
# Out:
# the r value is: 0.010207849881346156

# %%
# Southern Hemisphere
linear(southern_hemi_df["Wind Speed"],southern_hemi_df["Lat"],"Wind Speed v. Latitude (Southern)",(-55,60),"Latitude",
"Wind Speed")
# Out:
# the r value is: 0.0900016872951252

# %% [markdown]
# **Discussion about the linear relationship:** There is very little linear regression in the Southern hemisphere, more in the Northern hemisphere.
